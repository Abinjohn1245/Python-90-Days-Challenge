# %% [markdown]
# #Creating a List

# %%
# List is used for analysing data

# %%
items = []

# %%
items = ["Speaker", "Mic", "Mobile", "Laptop"]

# %% [markdown]
# # Accessing Elements

# %%
items = ["Speaker", "Mic", "Mobile", "Laptop"]

# %%
items[0]
# Out:
# 'Speaker'

# %%
items[2]
# Out:
# 'Mobile'

# %%
print(items[2])
# Out:
# Mobile

# %% [markdown]
# # Negative Indexing

# %%
items[-1]
# Out:
# 'pc'

# %% [markdown]
# # Slicing a List

# %%
items[0:3]
# Out:
# ['Speaker', 'Mic', 'Mobile']

# %%
items[0:]
# Out:
# ['Speaker', 'Mic', 'Mobile', 'Laptop']

# %%
items[0]
# Out:
# 'Speaker'

# %%
items[2:4]
# Out:
# ['Mobile', 'Laptop']

# %%
items[2:]
# Out:
# ['Mobile', 'Laptop']

# %% [markdown]
# # Modifying a List

# %%
items = ["Speaker", "Mic", "Mobile", "Laptop"]

# %%
items[3]="pc"

# %%
items
# Out:
# ['Speaker', 'Mic', 'Mobile', 'pc']

# %% [markdown]
# # Adding Elements to a List

# %%
items
# Out:
# ['Speaker', 'Mic', 'Mobile', 'pc']

# %%
items.append("charger")

# %%
items
# Out:
# ['Speaker', 'Mic', 'Mobile', 'pc', 'charger']

# %%
items.append("camera")

# %%
items
# Out:
# ['Speaker', 'Mic', 'Mobile', 'pc', 'charger', 'camera']

# %% [markdown]
# # Remove elements

# %%
items.remove("camera")

# %%
items
# Out:
# ['Speaker', 'Mic', 'Mobile', 'pc', 'charger']

# %% [markdown]
# # Delete elements

# %%
del items[-1]

# %%
items
# Out:
# ['Speaker', 'Mic', 'Mobile', 'pc']

# %%
items.clear()

# %%
items
# Out:
# []

# %%
items=['speaker','mic','mobile','pc','charger']

# %% [markdown]
# # Checking for existense

# %%
# are earbuds in the list?
print("earbuds" in items)
# Out:
# False

# %% [markdown]
# # Length of a list

# %%
items=['speaker','mic','mobile','pc','charger']

# %%
len(items)
# Out:
# 5

# %% [markdown]
# # List comprehension

# %%
# List comprehension means writing loops in a list

# %%
scores=[70,80,90,95]

# %%
for i in scores:
  print(i/2)
# Out:
# 35.0
# 40.0
# 45.0
# 47.5

# %%
[i/2 for i in scores]
# Out:
# [35.0, 40.0, 45.0, 47.5]
