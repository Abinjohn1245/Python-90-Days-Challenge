# %%
# int float str

# int - integer - -inf, .... -1, 0, 1, .... inf

# float - decimal - 0.1, 0.01, -0.1, 10.3

# str - characters - "a", 'a', "bus", "im in a bus", " ", "#", "@"

# %%
# Ctrl + (select all)
# Ctrl + / (comment all)

# %%
# Variables

# %%
100 + 25 + 40
# Out:
# 165

# %%
100*7
# Out:
# 700

# %%
100%7
# Out:
# 2

# %%
x=1
y=2
z=3

# %%
x+y+z
# Out:
# 6

# %%
x,y,z=1,2,3

# %%
x+y+z
# Out:
# 6
